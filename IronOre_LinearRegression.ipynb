# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#import seaborn
from sklearn.linear_model import LinearRegression 
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (15, 10),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
pylab.rcParams.update(params)

# %%
train = pd.read_csv('dataset/Iron ore fines 62% Fe CFR Futures Historical Data.csv')
#train = train.set_index('Date')

# %%
train[0:5]
# Out:
#            Date  Price   Open   High    Low Vol. Change %
# 0  Oct 16, 2018  70.79  70.79  70.79  70.79    -    0.03%
# 1  Oct 15, 2018  70.77  70.77  70.77  70.77    -    0.30%
# 2  Oct 12, 2018  70.56  70.56  70.56  70.56    -    0.36%
# 3  Oct 11, 2018  70.31  70.31  70.31  70.31    -   -0.41%
# 4  Oct 10, 2018  70.60  70.60  70.60  70.60    -    1.15%

# %%
train.tail()
# Out:
#              Date  Price   Open   High    Low   Vol. Change %
# 710  Jan 08, 2016  40.62  40.62  41.10  33.20  0.18K   -0.81%
# 711  Jan 07, 2016  40.95  40.95  41.00  33.30  0.20K    0.07%
# 712  Jan 06, 2016  40.92  40.92  41.55  36.00  0.51K   -1.45%
# 713  Jan 05, 2016  41.52  41.52  42.75  37.25  0.51K   -0.43%
# 714  Jan 04, 2016  41.70  41.70  43.10  37.80  0.18K    5.36%

# %%
#train = train.sort_values(by='Date')
#train.reset_index(inplace = True)

# %%
train = train.drop(['Vol.', 'Change %'], axis=1)

# %%
len(train)
# Out:
# 715

# %%
s = 0
l = 714
for i in range(round(len(train)/2)):
    s_temp = train.iloc[s].copy()
    l_temp = train.iloc[l].copy()
    train.iloc[s] = l_temp
    train.iloc[l] = s_temp
    s = s + 1
    l = l -1

# %%
train
# Out:
#              Date  Price   Open   High    Low
# 0    Jan 04, 2016  41.70  41.70  43.10  37.80
# 1    Jan 05, 2016  41.52  41.52  42.75  37.25
# 2    Jan 06, 2016  40.92  40.92  41.55  36.00
# 3    Jan 07, 2016  40.95  40.95  41.00  33.30
# 4    Jan 08, 2016  40.62  40.62  41.10  33.20
# ..            ...    ...    ...    ...    ...
# 710  Oct 10, 2018  70.60  70.60  70.60  70.60
# 711  Oct 11, 2018  70.31  70.31  70.31  70.31
# 712  Oct 12, 2018  70.56  70.56  70.56  70.56
# 713  Oct 15, 2018  70.77  70.77  70.77  70.77
# 714  Oct 16, 2018  70.79  70.79  70.79  70.79
#
# [715 rows x 5 columns]

# %%
from dateutil import parser
for i in range(len(train['Date'])):
    dt = parser.parse(train['Date'][i])
    train['Date'][i] = dt.strftime("%Y-%m-%d")
    #print(train['Date'][i], i)
train = train.set_index('Date')
# Out:
# C:\Users\sumon\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train = train[['Price']]

# %%
train
# Out:
#             Price
# Date
# 2016-01-04  41.70
# 2016-01-05  41.52
# 2016-01-06  40.92
# 2016-01-07  40.95
# 2016-01-08  40.62
# ...           ...
# 2018-10-10  70.60
# 2018-10-11  70.31
# 2018-10-12  70.56
# 2018-10-15  70.77
# 2018-10-16  70.79
#
# [715 rows x 1 columns]

# %%
# import plotly 
# plotly.tools.set_credentials_file(username='', api_key='')

# %%
import plotly.offline as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

#plot(data)

trace_high = go.Scatter(
                x=train.index,
                y=train['Price'],
                name = "Price",
                line = dict(color = '#17BECF'),
                opacity = 0.8)



data = [trace_high]

layout = go.Layout(title='Iron Ore Price', xaxis=dict(title='Date'),
                   yaxis=dict(title='(Price)'))
#fig = go.Figure(data=[data], layout=layout)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Irn Ore Price")
# Out:
# <div>
#
#
#             <div id="9172fa88-3c62-4973-8521-8650ddecbdde" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9172fa88-3c62-4973-8521-8650ddecbdde")) {
#                     Plotly.newPlot(
#                         '9172fa88-3c62-4973-8521-8650ddecbdde',
# ...

# %%
train['S_3'] = train['Price'].shift(1).rolling(window=3).mean() 
train['S_9']= train['Price'].shift(1).rolling(window=9).mean() 
train= train.dropna() 
X = train[['Price','S_3','S_9']]

# %%
t=.8 
t = int(t*len(train)) 
# Train dataset
X_tra = X[:t]
y_tra = y[:t]  
# Test dataset
X_val = X[t:]
y_val = y[t:]
#X_tra, X_val, y_tra, y_val = train_test_split(X, y, train_size=0.95)

# %%
X_tra
# Out:
#             Price        S_3        S_9
# Date
# 2016-02-24  46.58  46.513333  44.977778
# 2016-02-25  46.42  46.680000  45.375556
# 2016-02-26  46.50  46.570000  45.755556
# 2016-02-29  46.33  46.500000  45.956667
# 2016-03-01  49.08  46.416667  46.145556
# ...           ...        ...        ...
# 2018-04-03  64.31  68.383333  69.638889
# 2018-04-04  62.69  66.570000  68.955556
# 2018-04-05  62.74  64.233333  68.088889
# 2018-04-06  63.54  63.246667  67.185556
# 2018-04-09  64.14  62.990000  66.470000
#
# [543 rows x 3 columns]

# %%
linear = LinearRegression().fit(X_tra,y_tra)

# %%
print(round(linear.coef_[0],2))
print(round(linear.coef_[1],2))
print(round(linear.intercept_,2))
# Out:
# -0.58
# -1.41
# 11.47

# %%
predicted_price = linear.predict(X_val)

# %%
predicted_price = pd.DataFrame(predicted_price[:],index=y_val.index,columns = ['Price'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1680
# -> 1681         mgr = BlockManager(blocks, axes)
#    1682         mgr._consolidate_inplace()
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     142         if do_integrity_check:
# --> 143             self._verify_integrity()
#     144
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     344             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 345                 construction_error(tot_items, block.shape[1:], self.axes)
#     346         if len(self.items) != tot_items:
#
# ...

# %%
for i in range(len(predicted_price['Price'])):
    predicted_price['Price'][i] = round(predicted_price['Price'][i],2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-5522727e24c7> in <module>
# ----> 1 for i in range(len(predicted_price['Price'])):
#       2     predicted_price['Price'][i] = round(predicted_price['Price'][i],2)
#       3
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X_val
# Out:
#             Price        S_3        S_9
# Date
# 2018-04-10  65.00  63.473333  65.831111
# 2018-04-11  64.45  64.226667  65.285556
# 2018-04-12  64.36  64.530000  64.696667
# 2018-04-13  65.05  64.603333  64.103333
# 2018-04-16  64.00  64.620000  64.031111
# ...           ...        ...        ...
# 2018-10-10  70.60  69.226667  68.927778
# 2018-10-11  70.31  69.743333  69.147778
# 2018-10-12  70.56  70.236667  69.323333
# 2018-10-15  70.77  70.490000  69.550000
# 2018-10-16  70.79  70.546667  69.773333
#
# [136 rows x 3 columns]

# %%
y_val
# Out:
# Date
# 2018-03-02    76.96
# 2018-03-05    74.91
# 2018-03-06    75.22
# 2018-03-07    73.93
# 2018-03-08    72.71
#               ...
# 2018-10-10    70.60
# 2018-10-11    70.31
# 2018-10-12    70.56
# 2018-10-15    70.77
# 2018-10-16    70.79
# Name: Price, Length: 162, dtype: float64

# %%
# Creating trace1
trace1 = go.Scatter(
                x=X_val.index,
                y=y_val,
                name = "actual price",
                marker = dict(color = 'rgba(16, 112, 2, 0.8)'),
                opacity = 0.8)

# Creating trace2
trace2 = go.Scatter(
                    x = predicted_price.index,
                    y = predicted_price['Price'],
                    mode = "lines+markers",
                    name = "predicted rice",
                    #marker = dict(color = 'rgba(16, 112, 2, 0.8)'),
                    marker = dict(color = 'rgba(80, 26, 80, 0.8)'),
                    opacity = 0.8)
data = [trace1,trace2]
layout = dict(title = 'Iron Ore Price Prediction',
              xaxis= dict(title= 'Date')
             )
fig = dict(data = data, layout = layout)
py.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-1336ed3d08df> in <module>
#       9 # Creating trace2
#      10 trace2 = go.Scatter(
# ---> 11                     x = predicted_price.index,
#      12                     y = predicted_price['Price'],
#      13                     mode = "lines+markers",
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
y_val
# Out:
# Date
# 2018-04-03    64.31
# 2018-04-04    62.69
# 2018-04-05    62.74
# 2018-04-06    63.54
# 2018-04-09    64.14
#               ...
# 2018-10-10    70.60
# 2018-10-11    70.31
# 2018-10-12    70.56
# 2018-10-15    70.77
# 2018-10-16    70.79
# Name: Price, Length: 141, dtype: float64

# %%
trace_high = go.Scatter(
                x=predicted_price.index,
                y=predicted_price['Price'],
                mode = "lines+markers",
                name = "Price",
                marker = dict(color = 'rgba(80, 26, 80, 0.8)'),
                opacity = 0.8)



data = [trace_high]

layout = go.Layout(title='Iron Ore Price', xaxis=dict(title='Date'),
                   yaxis=dict(title='(Price)'))
#fig = go.Figure(data=[data], layout=layout)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "Irn Ore predict Price")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-b84b835e6e33> in <module>
#       1 trace_high = go.Scatter(
# ----> 2                 x=predicted_price.index,
#       3                 y=predicted_price['Price'],
#       4                 mode = "lines+markers",
#       5                 name = "Price",
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
predicted_price.plot(figsize=(15,5))

y_val.plot()

plt.legend(['predicted_price','actual_price'])

plt.ylabel("Iron Ore Price")
#plt.style.use("lightslategray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-7228e25822b9> in <module>
# ----> 1 predicted_price.plot(figsize=(15,5))
#       2
#       3 y_val.plot()
#       4
#       5 plt.legend(['predicted_price','actual_price'])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
X_tra.index
# Out:
# Index(['2016-01-15', '2016-01-18', '2016-01-19', '2016-01-20', '2016-01-21',
#        '2016-01-22', '2016-01-25', '2016-01-26', '2016-01-27', '2016-01-28',
#        ...
#        '2018-03-16', '2018-03-19', '2018-03-20', '2018-03-21', '2018-03-22',
#        '2018-03-23', '2018-03-26', '2018-03-27', '2018-03-28', '2018-03-29'],
#       dtype='object', name='Date', length=564)

# %%
train.tail()
# Out:
#             Price        S_3        S_9
# Date
# 2018-10-10  70.60  69.226667  68.927778
# 2018-10-11  70.31  69.743333  69.147778
# 2018-10-12  70.56  70.236667  69.323333
# 2018-10-15  70.77  70.490000  69.550000
# 2018-10-16  70.79  70.546667  69.773333

# %%
r2_score = linear.score(X_val,y_val)*100  

float("{0:.2f}".format(r2_score))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-19e30b2eeb9a> in <module>
# ----> 1 r2_score = linear.score(X_val,y_val)*100
#       2
#       3 float("{0:.2f}".format(r2_score))
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     408         y_pred = self.predict(X)
#     409         # XXX: Remove the check in 0.23
# --> 410         y_type, _, _, _ = _check_reg_targets(y, y_pred, None)
#     411         if y_type == 'continuous-multioutput':
#     412             warnings.warn("The default value of multioutput (not exposed in "
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      75
#      76     """
# ---> 77     check_consistent_length(y_true, y_pred)
#      78     y_true = check_array(y_true, ensure_2d=False)
# ...
